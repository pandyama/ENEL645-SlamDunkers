# %%
import matplotlib.pylab as plt
import pandas as pd
import pickle

# %%
history_it = pd.read_pickle("./Output/it_history_vgg16.pkl")
acc = history_it["accuracy"]
val_acc = history_it["val_accuracy"]
loss = history_it["loss"]
val_loss = history_it["val_loss"]
plt.figure()
plt.plot(acc, label="Training Accuracy")
plt.plot(val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.xlabel("epochs")
plt.ylabel("Accuracy")
plt.savefig("./Images/vgg16_with_imagenet.png")
plt.show()

# %%
history_it = pd.read_pickle("./Output/it_history_vgg16_withoutimagenet.pkl")
acc = history_it["accuracy"]
val_acc = history_it["val_accuracy"]
loss = history_it["loss"]
val_loss = history_it["val_loss"]
plt.figure()
plt.plot(acc, label="Training Accuracy")
plt.plot(val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.xlabel("epochs")
plt.ylabel("Accuracy")
plt.savefig("./Images/vgg16_without_imagenet.png")
plt.show()

# %%
history_it = pd.read_pickle("./Output/it_history_vgg16_50_epochs.pkl")
acc = history_it["accuracy"]
val_acc = history_it["val_accuracy"]
loss = history_it["loss"]
val_loss = history_it["val_loss"]
plt.figure()
plt.plot(acc, label="Training Accuracy")
plt.plot(val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.xlabel("epochs")
plt.ylabel("Accuracy")
plt.savefig("./Images/vgg16_with_imagenet_50_epochs.png")
plt.show()

# %%
history_it = pd.read_pickle("./Output/it_history_vgg16_50_epochs_dropout.pkl")
acc = history_it["accuracy"]
val_acc = history_it["val_accuracy"]
loss = history_it["loss"]
val_loss = history_it["val_loss"]
plt.figure()
plt.plot(acc, label="Training Accuracy")
plt.plot(val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.xlabel("epochs")
plt.ylabel("Accuracy")
plt.savefig("./Images/vgg16_with_imagenet_50_epochs_dropout.png")
plt.show()
